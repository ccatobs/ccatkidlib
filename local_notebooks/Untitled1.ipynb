# %%
import os
import time

#os.system('python3 queen_tui.py 21 1.1 -a 1')
#print(time.time())
#os.system('python3 queen_tui.py 21 1.1 -a 0')
#print(time.time())

# %%
print(time.time())
print(time.time())
# Out:
# 1690381399.4841135
# 1690381399.484278

# %%
t = time.gmtime(1690381592.993001)
time.asctime(t)
# Out:
# 'Wed Jul 26 14:26:32 2023'
