# %%
import matplotlib.pyplot as plt
# %matplotlib widget

# %%
import live_plotting

# %%
# %run live_plotting -r 31 -f "S21" -s "line" -t 20 -u 120 -p 1
# Out:
# Status: Drone 1.1: ip=192.168.2.100, to_run=False, running=True
# Status: Drone 1.2: ip=192.168.2.100, to_run=True, running=True
# Status: Drone 1.3: ip=192.168.2.100, to_run=False, running=True
# Status: Drone 1.4: ip=192.168.2.100, to_run=False, running=True
# Status: Drone 1.1: ip=192.168.2.100, to_run=False, running=True
# Status: Drone 1.2: ip=192.168.2.100, to_run=True, running=True
# Status: Drone 1.3: ip=192.168.2.100, to_run=False, running=True
# Status: Drone 1.4: ip=192.168.2.100, to_run=False, running=True
# Status: Drone 1.1: ip=192.168.2.100, to_run=False, running=True
# Status: Drone 1.2: ip=192.168.2.100, to_run=True, running=True
# Status: Drone 1.3: ip=192.168.2.100, to_run=False, running=True
# Status: Drone 1.4: ip=192.168.2.100, to_run=False, running=True
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ...
